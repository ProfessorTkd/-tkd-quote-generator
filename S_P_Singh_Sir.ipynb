# %% [markdown]
# <a href="https://colab.research.google.com/github/ProfessorTkd/-tkd-quote-generator/blob/main/S_P_Singh_Sir.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (15,15)
NSGA = [82.26, 17.5, 40, 48, 52, 69, 88,80,56,50,15, 17.5, 40, 48, 52, 69, 88,80,56,50]
MOPSO = [83.174, 8, 70, 1.5, 25, 12, 28,80,76,70,21, 17.5, 40, 48, 52, 69, 88,80,56,50]
LSMaOA = [84.088, 8, 70, 1.5, 25, 12, 28,30,10,34,23, 17.5, 40, 48, 52, 69, 88,80,56,50]
MOAE = [85.002, 17.5, 40, 48, 52, 69, 88,80,56,50,24, 17.5, 40, 48, 52, 69, 88,80,56,50]
PA = [86.83, 8, 70, 1.5, 25, 12, 28,80,76,70,25, 17.5, 40, 48, 52, 69, 88,80,56,50]
index = ["Jdbacl", "Biff", "Gaj", "Jsecurity","Lavalamp","Sfmis","Dom4j","Imsmart","Firebird","Omjstate","Lifeary","Beanbin","Heal","Inspirento","Quickserver","Nekumode","Openjms","Classviewer","geo-google","bpmail"]
df = pd.DataFrame({'NSGA-III': NSGA,'MOPSO': MOPSO,'LSMaOA': LSMaOA,'MOAE': MOAE,'Proposed Algorithm': PA}, index=index)
#df.plt.figure(figsize=(20, 20))
ax = df.plot.barh(width=0.6)
plt.xlabel("Projects")
plt.ylabel("MC Value")
plt.title("Please insert title")
# Out:
# Text(0.5, 1.0, 'Please insert title')
